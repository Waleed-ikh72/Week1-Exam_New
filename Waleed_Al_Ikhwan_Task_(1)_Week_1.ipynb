# %% [markdown]
# <a href="https://colab.research.google.com/github/Waleed-ikh72/Week1-Exam_New/blob/main/Waleed_Al_Ikhwan_Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# ### Handle Missing Values

# %%
#check the missing values
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
# Let's first handle the categrical missing values. We can either use the mode to replace the missing values
#or we can use backfill or forwardfill  to take the previous record.

df['Educational_level'].fillna(df['Educational_level'].mode()[0], inplace=True)
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0], inplace=True)
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace=True)
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0], inplace=True)
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0], inplace=True)
df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0], inplace=True)
df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0], inplace=True)
df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0], inplace=True)
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0], inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace=True)
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0], inplace=True)
df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0], inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace=True)
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace=True)
df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode()[0], inplace=True)
df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0], inplace=True)

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Time']
# regarding the inconsistnet, we can have time hour, minute, and seconds seperately.
# Or we can make them all consistent in case of any
df['Day_of_week'] = df['Day_of_week'].replace({'monday': 'Monday', 'tuesday': 'Tuesday'})
df['Day_of_week'].value_counts()
# Out:
# Day_of_week
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: count, dtype: int64

# %%
df['hour'] = df['Time'].str.split(':').str[0]
df['minute'] = df['Time'].str.split(':').str[1]
df['second'] = df['Time'].str.split(':').str[2]

# %%
display(df)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.isna().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# majority of the column in this dataset have Date type of categrical except
#Number_of_vehicles_involved & Number_of_casualties are numerical values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Service_year_of_vehicle      12316 non-null  object
#  10  Defect_of_vehicle            12316 non-null  object
#  11  Area_accident_occured        12316 non-null  object
#  12  Lanes_or_Medians             12316 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Service_year_of_vehicle      12316 non-null  object
#  10  Defect_of_vehicle            12316 non-null  object
#  11  Area_accident_occured        12316 non-null  object
#  12  Lanes_or_Medians             12316 non-null  object
# ...

# %%
df.tail() # will show the last 5 records
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311  Junior high school                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                 Unknown  ...
# ...

# %%
df.head() # will show the first 5 records
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr           Automobile
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Age_band_of_casualty  \
# ...

# %%
display(df)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.sample() # will take reandom record and show me its information
# Out:
#          Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 960  19:02:00    Thursday              18-30          Male
#
#       Educational_level Vehicle_driver_relation Driving_experience  \
# 960  Junior high school                Employee             5-10yr
#
#     Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 960      Automobile            Owner                 Unknown  ...
#
#     Age_band_of_casualty Casualty_severity Work_of_casuality  \
# 960                18-30                 3            Driver
#
#     Fitness_of_casuality Pedestrian_movement Cause_of_accident  \
# 960               Normal    Unknown or other             Other
#
#     Accident_severity hour minute second
# 960     Slight Injury   19     02     00
#
# [1 rows x 35 columns]

# %%
df.duplicated().sum() # will show the number of duplicated records
# Out:
# 0

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df['Number_of_vehicles_involved']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 12311    2
# 12312    2
# 12313    1
# 12314    2
# 12315    2
# Name: Number_of_vehicles_involved, Length: 12316, dtype: int64

# %%
df['Number_of_vehicles_involved'].max() # the max number of vehicales involved in the accedinet is 7.
# Out:
# 7

# %%
df['Number_of_casualties']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 12311    1
# 12312    1
# 12313    1
# 12314    1
# 12315    1
# Name: Number_of_casualties, Length: 12316, dtype: int64

# %%
df['Number_of_casualties'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Number_of_casualties'].max()
# Out:
# 8

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
df['Age_band_of_driver'].value_counts().plot(kind='bar')
# Majority of the studies are ages between 18-30 which they are more than 4000.
# the second majority of the studies are between 31-50.
# Out:
# <Axes: xlabel='Age_band_of_driver'>

# %%
df['Age_band_of_driver'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Type_of_vehicle'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type_of_vehicle'>

# %% [markdown]
# **bold text**### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df[['Age_band_of_driver','Accident_severity']].value_counts()
# Out:
# Age_band_of_driver  Accident_severity
# 18-30               Slight Injury        3605
# 31-50               Slight Injury        3492
# Unknown             Slight Injury        1370
# Over 51             Slight Injury        1304
# Under 18            Slight Injury         644
# 18-30               Serious Injury        604
# 31-50               Serious Injury        541
# Over 51             Serious Injury        257
# Unknown             Serious Injury        172
# Under 18            Serious Injury        169
# 18-30               Fatal injury           62
# 31-50               Fatal injury           54
# Over 51             Fatal injury           24
# Under 18            Fatal injury           12
# Unknown             Fatal injury            6
# Name: count, dtype: int64

# %%
df[['Age_band_of_driver','Accident_severity']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age_band_of_driver,Accident_severity'>

# %%
grouped_df = df.groupby(['Age_band_of_driver','Accident_severity'])
grouped_df.size()
# Out:
# Age_band_of_driver  Accident_severity
# 18-30               Fatal injury           62
#                     Serious Injury        604
#                     Slight Injury        3605
# 31-50               Fatal injury           54
#                     Serious Injury        541
#                     Slight Injury        3492
# Over 51             Fatal injury           24
#                     Serious Injury        257
#                     Slight Injury        1304
# Under 18            Fatal injury           12
#                     Serious Injury        169
#                     Slight Injury         644
# Unknown             Fatal injury            6
#                     Serious Injury        172
#                     Slight Injury        1370
# dtype: int64

# %%
grouped_agg_df = df.groupby(['Age_band_of_driver','Accident_severity']).agg(
    Total_Accedient=('Accident_severity','count'),
    Total_casualties=('Number_of_casualties','sum')
    )
grouped_agg_df
# Out:
#                                       Total_Accedient  Total_casualties
# Age_band_of_driver Accident_severity
# 18-30              Fatal injury                    62               164
#                    Serious Injury                 604               941
#                    Slight Injury                 3605              5614
# 31-50              Fatal injury                    54               125
#                    Serious Injury                 541               765
#                    Slight Injury                 3492              5508
# Over 51            Fatal injury                    24                49
#                    Serious Injury                 257               409
#                    Slight Injury                 1304              2067
# Under 18           Fatal injury                    12                24
#                    Serious Injury                 169               324
# ...

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity', 'hour', 'minute', 'second'],
#       dtype='object')

# %%
df[['Driving_experience','Educational_level']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Driving_experience,Educational_level'>

# %%
df['Day_of_week'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Day_of_week'>

# %%
df[['Day_of_week','Age_band_of_driver']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Day_of_week,Age_band_of_driver'>

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
nv = df[['Number_of_vehicles_involved','Number_of_casualties']]
correlation = nv.corr()
sns.heatmap(correlation, annot=True,vmin = -1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x='Number_of_vehicles_involved', y='Number_of_casualties', data=df)
# Out:
# <Axes: xlabel='Number_of_vehicles_involved', ylabel='Number_of_casualties'>

# %%
sns.histplot(df['Number_of_vehicles_involved'],kde = True)
# Out:
# <Axes: xlabel='Number_of_vehicles_involved', ylabel='Count'>

# %%
sns.histplot(df['Number_of_casualties'],kde = True)
# Out:
# <Axes: xlabel='Number_of_casualties', ylabel='Count'>

# %%
df[['Sex_of_driver','Age_band_of_driver']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex_of_driver,Age_band_of_driver'>

# %%
df[['Vehicle_driver_relation','Age_band_of_driver']].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data
#
# 1.   List item
# 2.   List item
#
# analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# From the above analysis
# Majority of the studies are ages between 18-30 which they are more than 4000.
# the second majority of the studies are between 31-50.
# the data contains number of records of 12316 and number of columns of 32
# The number of ages generation is between 18-30 as shown in the pie chart.
# The type of viechels are automobile is the most in the data
# We can conclude that ages between 18-30 are the majority of having a slight injury on the other hand the same ages
# having a fatal injury.
# We can notice that the acciednt occaginally happened in the Friday. Which makes sence if this data is either was
# obtained from Middle East or USA. As of it USA and Middle East are off work on Friday. And the ages are from 31-50
# making the accidents
# Conclusion: The accedients happened on Friday which score with ages of 31-50, and the gender are male between 18-30.
